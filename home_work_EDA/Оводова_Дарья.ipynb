# %% [markdown]
# # Вариант 2

# %% [markdown]
# Обязательные требования:
# 1. Все графики должны быть подписаны (заголовок, оси)
# 2. К каждому графику должны быть представлены выводы (что вы увидели, какие зависимости, какие особенности, что тот или иной график говорит вам о данных).
# 3. Графики должны быть читабельными (если сделаете такой масштаб, что ничего не будет видно или все будет налазить друг на друга - это не засчитывается).

# %% [markdown]
# ## Загрузка данных

# %% [markdown]
# Вам дан датасет о качестве воздуха в различных регионах: `pollution_dataset.csv`
#
# Основные характеристики:
#
# - Температура (°C): Средняя температура региона.
# - Влажность (%): Относительная влажность, зарегистрированная в регионе.
# - Концентрация PM2.5 (мкг/м³): Уровни мелких твердых частиц.
# - Концентрация PM10 (мкг/м³): Уровни крупных твердых частиц.
# - Концентрация NO2 (ppb): Уровни диоксида азота.
# - Концентрация SO2 (ppb): Уровни диоксида серы.
# - Концентрация CO (ppm): Уровни оксида углерода.
# - Близость к промышленным зонам (км): Расстояние до ближайшей промышленной зоны.
# - Плотность населения (чел./км²): Количество людей на квадратный километр в регионе.
# - Уровни качества воздуха:
#     - Хорошее (Good): Чистый воздух с низким уровнем загрязнения.
#     - Умеренный (Moderate): Приемлемое качество воздуха, но присутствуют некоторые загрязняющие вещества.
#     - Плохой (Poor): Заметное загрязнение, которое может вызвать проблемы со здоровьем у чувствительных групп.
#     - Опасный (Hazardous): Сильно загрязненный воздух, представляющий серьезные риски для здоровья населения.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("pollution_dataset.csv")
df
# Out:
#       Temperature  Humidity  PM2.5   PM10   NO2   SO2    CO  \
# 0            29.8      59.1    5.2   17.9  18.9   9.2  1.72
# 1            28.3      75.6    2.3   12.2  30.8   9.7  1.64
# 2            23.1      74.7   26.7   33.8  24.4  12.6  1.63
# 3            27.1      39.1    6.1    6.3  13.5   5.3  1.15
# 4            26.5      70.7    6.9   16.0  21.9   5.6  1.01
# ...           ...       ...    ...    ...   ...   ...   ...
# 4995         40.6      74.1  116.0  126.7  45.5  25.7  2.11
# 4996         28.1      96.9    6.9   25.0  25.3  10.8  1.54
# 4997         25.9      78.2   14.2   22.1  34.8   7.8  1.63
# 4998         25.3      44.4   21.4   29.0  23.7   5.7  0.89
# 4999         24.1      77.9   81.7   94.3  23.2  10.5  1.38
#
#       Proximity_to_Industrial_Areas  Population_Density Air Quality
# 0                               6.3                 319    Moderate
# 1                               6.0                 611    Moderate
# 2                               5.2                 619    Moderate
# 3                              11.1                 551        Good
# 4                              12.7                 303        Good
# ...                             ...                 ...         ...
# 4995                            2.8                 765   Hazardous
# 4996                            5.7                 709    Moderate
# 4997                            9.6                 379    Moderate
# 4998                           11.6                 241        Good
# 4999                            8.3                 461    Moderate
#
# [5000 rows x 10 columns]

# %% [markdown]
# ## График 1

# %% [markdown]
# Построить точечный график зависимости переменной `NO2` от `CO` с учётом третей переменной `Air Quality`.

# %%
colors = {'Good': 'green', 'Moderate': 'yellow', 'Poor': 'orange', 'Hazardous': 'red'}
plt.figure(figsize=(10, 8))
for Air_Quality in df['Air Quality'].unique():
    filtered = df[df['Air Quality'] == Air_Quality]
    plt.scatter(filtered['CO'], filtered['NO2'], color=colors[Air_Quality])
plt.title('Зависимость NO2 от CO с учетом Air Quality')
plt.xlabel('CO')
plt.ylabel('NO2')
plt.grid()
plt.show()

# %% [markdown]
# С ухудшением качества воздуха растёт количество NO2 и CO, содержащихся в воздухе

# %% [markdown]
# ## График 2

# %% [markdown]
# Постройте 4 графика на одной фигуре, как расположить координатные плоскости - это на ваше усмотрение.
#
# Это должны быть графики для следующих переменных:
# - `Air Quality` - гистограмма
# - `Population_Density` - график распределения
# - `Temperature` - график распределения
# - `Humidity` - график распределения
#
# Каждый график должен быть своего цвета, также задайте цвет отличный от белого для бекграунда всей фигуры.

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 12))
fig.set_facecolor("lightcoral")

ax[0, 0].hist(df["Air Quality"], color="red")
ax[0, 0].set_title("Гистограмма уровня качества воздуха")
ax[0, 0].set_xlabel("Качество воздуха")
ax[0, 0].set_ylabel("Частота")

sns.distplot(df["Population_Density"], color='green', ax=ax[0, 1])
ax[0, 1].set_title("График распределения плотности населения")
ax[0, 1].set_xlabel("Плотность населения (чел./км²)")

sns.distplot(df["Temperature"], color='orange', ax=ax[1, 0])
ax[1, 0].set_title("График распределения температуры")
ax[1, 0].set_xlabel("Температура (°C)")

sns.distplot(df["Humidity"], ax=ax[1, 1])
ax[1, 1].set_title("График распределения влажности")
ax[1, 1].set_xlabel("Влажность (%)")
plt.show()
# Out:
# <ipython-input-4-8b170dca1f4a>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Population_Density"], color='green', ax=ax[0, 1])
# <ipython-input-4-8b170dca1f4a>:13: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Temperature"], color='orange', ax=ax[1, 0])
# <ipython-input-4-8b170dca1f4a>:17: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Humidity"], ax=ax[1, 1])

# %% [markdown]
# С помощью этих графиков мы можем работать с каждым графиков в отдельности (анпример узнать наиболее/наименее часто встречающиеся значения)

# %% [markdown]
# ## График 3

# %% [markdown]
# Визуализируйте матрицу корреляции в виде heatmap.
#
# Все должно быть ЧИТАБЕЛЬНО!

# %%
plt.figure(figsize=(12,10))

corr_matrix = df.corr(numeric_only=True)
sns.heatmap(corr_matrix, xticklabels=df.corr(numeric_only=True).columns, yticklabels=df.corr(numeric_only=True).columns, cmap='Blues', center=0, annot=True)

plt.title('Матрица корреляции', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# Переменная PM10 зависит от PM2.5

# %% [markdown]
# ## График 4

# %% [markdown]
# Постройте графики boxplot для следующих переменных:
# - `CO` с учетом переменной `Air Quality`
# - `NO2` с учетом переменной `Air Quality`
#
# Как их построить решаете самостоятельно.
#
# Проанализируйте выборы.

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 7))

sns.boxplot(x = df["Air Quality"], y = df["CO"], ax=ax[0])
ax[0].set_title("Boxplot CO по уровням качества воздуха")
ax[0].set_xlabel("Уровень качества воздуха")
ax[0].set_ylabel("CO")

sns.boxplot(x = df["Air Quality"], y = df["NO2"], ax=ax[1])
ax[1].set_title("Boxplot NO2 по уровням качества воздуха")
ax[1].set_xlabel("Уровень качества воздуха")
ax[1].set_ylabel("NO2")

plt.show()

# %% [markdown]
# Маленькое количество выбросов (из 5000 значений)

# %% [markdown]
# ## График 5

# %% [markdown]
# Постройте heatmap для отображения пропусков в данных.

# %%
plt.figure(figsize=(15,7))

cmap = sns.cubehelix_palette(as_cmap=True, light=.9)

sns.heatmap(df.isna().transpose(), cmap=cmap, cbar_kws={'label': 'Missing Data'})
# Out:
# <Axes: >

# %% [markdown]
# В данном датасете нет пропусков данных

# %% [markdown]
# ## График 6

# %% [markdown]
# Постройте график среднего значения переменной `PM10` в зависимости от переменной `Air Polution`.

# %%
df2 = df.groupby("Air Quality")["PM10"].mean().reset_index()

fig, ax = plt.subplots()
ax.bar(df2["Air Quality"], df2["PM10"])
plt.title("Среднее значение PM10 в зависимости от уровня качества воздуха")
plt.xlabel("Качество воздуха")
plt.ylabel("Среднее значение PM10 (мкг/м³)")
# Out:
# Text(0, 0.5, 'Среднее значение PM10 (мкг/м³)')

# %% [markdown]
# Среднее занчение переменной PM10 самое большое у опасного воздуха, а самое маленькое у хорошего

# %% [markdown]
# ## График 7

# %% [markdown]
# Найдите любой **нестандартный** график и постройте его. На ваш выбор.

# %%
plt.figure(figsize=(10,8))
sns.pairplot(df, kind="reg", hue="Air Quality")
plt.show()

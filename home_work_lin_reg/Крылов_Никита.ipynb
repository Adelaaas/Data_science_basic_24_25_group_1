# %%
# !pip install numpy
# !pip install pandas

# %% [markdown]
# ##NumPy

# %%
import numpy as np
with open('input.txt') as file:
    x = np.array([[int(digit) for digit in line.split()] for line in file])
y = np.zeros((x.shape[0], x.shape[1]), int)
print(x[x==0])
# Out:
# [0 0 0 0 0]

# %%
def get_nearest(x):
  if x[x>0].min() < (-1)*x[x<0].max():
    return x[x>0].min()
  else:
    return x[x<0].max()

# %%
x = input()
x = list(map(int, x.split()))
x = np.array(x, int)
print(get_nearest(x))
# Out:
# 27 14 22 12 -22 -35 -40 -33 35 -43 -1
# -1

# %%
def make_chess_matrix(n):
  arr = np.zeros((n, n), int)
  arr[0::2, 1::2] += 1
  arr[1::2, 0::2] += 1
  return arr

# %%
n = int(input())
arr = make_chess_matrix(n)
arr = str(arr)
arr = arr.replace(" [", "")
arr = arr.replace("]", "")
arr = arr.replace("[", "")
print(arr)
# Out:
# 2
# 0 1
# 1 0

# %%
def symetric(x):
  dfdfv

# %% [markdown]
# ##Pandas

# %%
import pandas as pd
import numpy as np
x = input()
list1 = list(map(int, x.split(',')))
arr1 = np.array(list1, int)
print(arr1)
# Out:
# 38,28,14
# [38 28 14]

# %% [markdown]
# ###A

# %%
with open('input1.csv') as file:
    arr = np.array([[int(digit) for digit in line.split(',')] for line in file])

dataFr = pd.DataFrame(arr)

print(dataFr.shape[0])
print(dataFr.shape[1])
# Out:
# 5
# 3

# %%
dataFr1 = pd.read_csv('input1.csv')
print(dataFr1.shape[0] + 1)
print(dataFr1.shape[1])
# Out:
# 5
# 3

# %% [markdown]
# ###B

# %%
import pandas as pd
import numpy as np

#data = pd.DataFrame(columns=['Имя', 'Возраст', 'Балл'], dtype=[str, int, int])
data = pd.read_csv('input.csv')
#data = pd.DataFrame(data, dtype=[str, int, int])
#data[1] = data[1].astype(int)
#data[2] = data[2].astype(int)

#print(data['Имя'].value_counts())
x = data['Имя'].value_counts()
x2 = x[x == x.iloc[0]]
x2 = x2.sort_index()
x2 = x2.to_dict()
for key, value in x2.items():
  print("{0} {1}".format(key,value))
#x2 = pd.Series(x2)
#print(x2)
# Out:
# Вячеслав 2

# %% [markdown]
# ###C

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('input.csv')

x = data['Имя'].unique()
x = sorted(x)
print(*x)
# Out:
# Амалия Артем Виолетта Диана Екатерина Захар Иван Максим Михаил Наталья искандер

# %% [markdown]
# ###D

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('input.csv')

x = data.isna().sum()
print('Название_колонки,Количество_NaN')
for i in list(x.items()):
  print(f'{i[0]},{i[1]}')
# Out:
# Название_колонки, Количество_NaN
# Имя,4
# Возраст,2
# Балл,0

# %% [markdown]
# ###E

# %%
import pandas as pd
import numpy as np
import re

data = pd.read_csv('input.csv')

x = data.loc[data['Возраст'] > 35, 'Имя']
ans = list(x)
print(*ans)
# Out:
# Максим Диана Артем

# %% [markdown]
# ###F

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('input.csv')

x = data.loc[data['brand'] == 'chevrolet']
ans = x['price'].mean()
print(round(ans, 2))
# Out:
# 14200.0

# %% [markdown]
# ###G

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('input.csv')

x = data['brand'].unique()
marks = dict.fromkeys(x)
marks = dict(sorted(marks.items()))
for i in marks.keys():
  cur_mark = data.loc[data['brand'] == i]
  unic_colors = cur_mark['color'].unique()
  new_val = len(unic_colors)
  marks[i] = new_val
print(marks)
# Out:
# {'chevrolet': 1, 'dodge': 1, 'ford': 4, 'gmc': 1, 'nissan': 1}

# %% [markdown]
# ###H

# %%
df=pd.DataFrame(['R','R/G','G'], columns=['color'])
df
# Out:
#   color
# 0     R
# 1   R/G
# 2     G

# %%
df['color'].value_counts()
# Out:
# color
# R      1
# R/G    1
# G      1
# Name: count, dtype: int64

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('input.csv')

common_of_games = data['Domains'].value_counts()
most_common_games = common_of_games.loc[common_of_games == common_of_games.max()]
for i in list(most_common_games.items()):
  print(*i)
# Out:
# Family Games 2
# Strategy Games 2

# %%
list(most_common_games.items())
# Out:
# [('Family Games', 2), ('Strategy Games', 2)]

# %%
most_common_games.index
# Out:
# Index(['Family Games', 'Strategy Games'], dtype='object', name='Domains')

# %% [markdown]
# ###I

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('input.csv')
ans = 2021 - data['Year Published'].mean()

print(round(ans, 2))
# Out:
# 16.2

# %% [markdown]
# ###J

# %%
import pandas as pd
import numpy as np
import re

data = pd.read_csv('input.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-f66db9651469> in <cell line: 5>()
#       3 import re
#       4
# ----> 5 data = pd.read_csv('input.csv')
#       6
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('input.csv')
x = data.loc[data['Domains'].str.contains('Strategy Games')]
x.loc[:, 'Rating Average'] = x.loc[:, 'Rating Average'].str.replace(',', '.')
x.loc[:, 'Rating Average'] = x.loc[:, 'Rating Average'].astype(float)
ans = x['Rating Average'].mean()

print(ans)
# Out:
# 6.13

# %% [markdown]
# ###K

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('input.csv')
data.loc['PPI'] = count(data['ScreenResolution'], data['Inches'])

print(data)
# Out:
#    laptop_ID Company  Inches             ScreenResolution  \
# 0        343      HP    15.6            Full HD 1920x1080
# 1        695    Dell    15.6                     1366x768
# 2        315  Lenovo    13.3  IPS Panel Full HD 1920x1080
# 3       1017      HP    14.0                     1366x768
# 4         74    Dell    15.6            Full HD 1920x1080
#
#                           Cpu  Ram  Weight
# 0  Intel Core i5 7200U 2.5GHz  8GB  1.84kg
# 1    Intel Core i3 6006U 2GHz  4GB   2.2kg
# 2  Intel Core i5 7200U 2.5GHz  8GB   1.1kg
# 3  Intel Core i5 7200U 2.5GHz  4GB  1.64kg
# 4  Intel Core i7 8550U 1.8GHz  8GB   2.2kg

# %%
def count(screen_resolution, inches):
  screen_resolution.str.find('x')

# %%
x = input()
x = list(map(int, x.split(',')))
x = np.array(x, int)
# Out:
# 38,28,14

# %% [markdown]
# ##Voice

# %%
# !pip install speakerpy

# %%
from lib_speak import Speaker
from lib_sl_text import SeleroText

text = SeleroText("Пример текста для синтеза речи")
speaker = Speaker(model_id="ru_v3", language="ru", speaker="aidar", device="cpu")
speaker.speak(text=text, sample_rate=48000, speed=1.0)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-8e5f70574a69> in <cell line: 1>()
# ----> 1 from lib_speak import Speaker
#       2 from lib_sl_text import SeleroText
#       3
#       4 text = SeleroText("Пример текста для синтеза речи")
#       5 speaker = Speaker(model_id="ru_v3", language="ru", speaker="aidar", device="cpu")
#
# ModuleNotFoundError: No module named 'lib_speak'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from lib_speak import Speaker
from lib_sl_text import SeleroText

text = SeleroText("Пример текста для синтеза речи")
speaker = Speaker(model_id="ru_v3", language="ru", speaker="aidar", device="cpu")
speaker.to_mp3(text=text, name_text="Текст", sample_rate=48000, audio_dir=pathlib.Path(__file__).parent.parent / "mp3", speed=1.0)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-53fa8958d14b> in <cell line: 1>()
# ----> 1 from lib_speak import Speaker
#       2 from lib_sl_text import SeleroText
#       3
#       4 text = SeleroText("Пример текста для синтеза речи")
#       5 speaker = Speaker(model_id="ru_v3", language="ru", speaker="aidar", device="cpu")
#
# ModuleNotFoundError: No module named 'lib_speak'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install transformers sentencepiece --quiet

# %%
import torch
from transformers import T5ForConditionalGeneration, T5Tokenizer
model_name = "cointegrated/rut5-base-multitask"
tokenizer = T5Tokenizer.from_pretrained(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name)

def generate(text, **kwargs):
    inputs = tokenizer(text, return_tensors='pt')
    with torch.no_grad():
        hypotheses = model.generate(**inputs, num_beams=5, **kwargs)
    return tokenizer.decode(hypotheses[0], skip_special_tokens=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-ae6735d16c40> in <cell line: 4>()
#       2 from transformers import T5ForConditionalGeneration, T5Tokenizer
#       3 model_name = "cointegrated/rut5-base-multitask"
# ----> 4 tokenizer = T5Tokenizer.from_pretrained(model_name)
#       5 model = T5ForConditionalGeneration.from_pretrained(model_name)
#       6
#
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py in from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, trust_remote_code, *init_inputs, **kwargs)
#    2211                 logger.info(f"loading file {file_path} from cache at {resolved_vocab_files[file_id]}")
#    2212
# -> 2213         return cls._from_pretrained(
#    2214             resolved_vocab_files,
#    2215             pretrained_model_name_or_path,
#
# ...

# %% [markdown]
# ##Plots

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('sales_dataset.csv')
#print(data)

# %%
data.head(10)
# Out:
#    Unnamed: 0 property_type     price     location       city  \
# 0           0          Flat  10000000         G-10  Islamabad
# 1           1          Flat   6900000         E-11  Islamabad
# 2           2         House  16500000         G-15  Islamabad
# 3           3         House  43500000    Bani Gala  Islamabad
# 4           4         House   7000000  DHA Defence  Islamabad
# 5           5         House  34500000  Ghauri Town  Islamabad
# 6           6         House  27000000  Korang Town  Islamabad
# 7           7          Flat   7800000         E-11  Islamabad
# 8           8         House  50000000  DHA Defence  Islamabad
# 9           9     Penthouse  40000000         F-11  Islamabad
#
#        province_name   latitude  longitude  baths   purpose  bedrooms  \
# 0  Islamabad Capital  33.679890  73.012640      2  For Sale         2
# 1  Islamabad Capital  33.700993  72.971492      3  For Sale         3
# 2  Islamabad Capital  33.631486  72.926559      6  For Sale         5
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153430 entries, 0 to 153429
# Data columns (total 19 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Unnamed: 0     153430 non-null  int64
#  1   property_type  153430 non-null  object
#  2   price          153430 non-null  int64
#  3   location       153430 non-null  object
#  4   city           153430 non-null  object
#  5   province_name  153430 non-null  object
#  6   latitude       153430 non-null  float64
#  7   longitude      153430 non-null  float64
#  8   baths          153430 non-null  int64
#  9   purpose        153430 non-null  object
#  10  bedrooms       153430 non-null  int64
#  11  date_added     153430 non-null  object
#  12  agency         153430 non-null  object
#  13  agent          153430 non-null  object
#  14  Area_in_Marla  153430 non-null  float64
#  15  Year           153430 non-null  int64
#  16  Month          153430 non-null  int64
# ...

# %%
data['Area_in_Marla'].max()
# Out:
# 16000.0

# %% [markdown]
# ###График 1

# %%
fig, ax = plt.subplots(figsize=(15,15))
#x = data['price']
#y = data['Area_in_Marla']
#ax.scatter()
#plt.figure(figsize=(30,30))
#x1 = data1['price'].copy()
scat = sns.scatterplot(x=data['price'], y=data['Area_in_Marla'], hue = data['purpose'], s = 30)
scat.set_ylabel("Area in Marla", fontsize=20)
scat.set_xlabel("Property", fontsize=20);
plt.show()

# %% [markdown]
# Вывод: Большая часть жилья имеет площадь менее 500 марл, то есть менее 500*272,25/10,774 = 12634,58 м^2. Но этот график малоинформативен, т.к. большая часть занчений сгруппирована значительно плотнее, чем можно рассмотреть на графике с таким масштабом

# %% [markdown]
# ###График 2

# %%
fig, axes = plt.subplots(2,2,figsize=(20,20))
fig.set_facecolor('#87CEFA')
hist1 = sns.countplot(ax=axes[0,0], x=data['property_type'], color='#FF6347')
hist2 = sns.countplot(ax=axes[0,1], x=data['city'], color='#2F4F4F')
hist3 = sns.countplot(ax=axes[1,0], x=data['purpose'], color='#000080')
hist4 = sns.countplot(ax=axes[1,1], x=data['bedrooms'], color='#BDB76B')

hist1.set_ylabel("Number of property with this type", fontsize=20)
hist1.set_xlabel("Type of property", fontsize=20);
hist2.set_ylabel("Number of property in city", fontsize=20)
hist2.set_xlabel("Cities", fontsize=20);
hist3.set_ylabel("Number of property with this purpose", fontsize=20)
hist3.set_xlabel("Purpose", fontsize=20);
hist4.set_ylabel("Number of property with this number of bedrooms", fontsize=20)
hist4.set_xlabel("Number of bedrooms", fontsize=20);

axes[0,0].set_facecolor('#5F9EA0')
axes[0,1].set_facecolor('#4682B4')
axes[1,0].set_facecolor('#3CB371')
axes[1,1].set_facecolor('#228B22')
plt.show()

# %% [markdown]
# Вывод: Весь датасет собран на данных о жилье из 5 крупных городов Пакистана. Большая часть жилья продаётся, а не сдаётся в аренду => в Пакистане слабо развит туризм, а местные жители оттуда уезжают. В основном в домах по 2-5 спален, в данных больше всего домов и квартир.

# %% [markdown]
# ###График 3

# %%
plt.figure(figsize=(12,10))
corr_matrix = data.corr(numeric_only=True)
sns.heatmap(corr_matrix, xticklabels=data.corr(numeric_only=True).columns, yticklabels=data.corr(numeric_only=True).columns, cmap='Blues', center=0, annot=True)
# color pallete sns
# Decorations
plt.title('Correlogram of property', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# Вывод: наибольшая зависимостьь наблюдается между месяцем и сезоном, широтой и долготой, количеством спален и ванных. Последняя зависимость обусловлена тем, что в нормальных условиях определённому количеству людей необходимо примерно одинаковое количество спален, ванных, парковок и т.д., поэтому если кол-во людей удваивается, то удваивается и количество спален, сан. узлов и т.д.

# %% [markdown]
# ###График 4

# %%
new_data = data['purpose'].value_counts()
print(new_data.size)
# Out:
# 2

# %%
fig, axes = plt.subplots(new_data.size, 2, figsize=(15,30))
# ax[0].scatter()
for i in range(0, new_data.size):
  pict1 = sns.boxplot(data['price'].loc[data['purpose'] == new_data.index[i]], ax=axes[i, 0], width=0.3)
  pict2 = sns.boxplot(data['bedrooms'].loc[data['purpose'] == new_data.index[i]], ax=axes[i, 1], width=0.3)
  pict1.set_title(new_data.index[i], fontsize=14)
  pict2.set_title(new_data.index[i], fontsize=14)
plt.show()

# %% [markdown]
# Вывод: количество спален в продаваемом и сдаваемом в аренду жилье примерно одинаковое - менее 5, но цена продаваемого жилья примерно в 100 раз больше цены аренды.

# %% [markdown]
# ###График 5

# %%
plt.figure(figsize=(15,7))

cmap = sns.cubehelix_palette(as_cmap=True, light=.9)

sns.heatmap(data.isna().transpose(), cmap=cmap,
            cbar_kws={'label': 'Missing Data'})
plt.title('Heatmap of misses in data', fontsize=22)
plt.show()

# %%
data.isna().sum()
# Out:
# Unnamed: 0       0
# property_type    0
# price            0
# location         0
# city             0
# province_name    0
# latitude         0
# longitude        0
# baths            0
# purpose          0
# bedrooms         0
# date_added       0
# agency           0
# agent            0
# Area_in_Marla    0
# Year             0
# Month            0
# Day              0
# Season           0
# dtype: int64

# %% [markdown]
# ###График 6

# %%
seasons = data['Season'].value_counts()
new_dict = dict()
for i in seasons.index:
  new_dict[i] = data['price'].loc[data['Season'] == i].mean()
#data6 = pd.DataFrame()
print(new_dict)
# Out:
# {3: 16032884.88712792, 2: 21604664.394231662, 1: 17465716.70132888, 4: 14168959.982322901}

# %%
fig, ax = plt.subplots(figsize=(10,10))
grphik = sns.lineplot(x=new_dict.keys(), y=new_dict.values())
grphik.set_ylabel("Mean Prices / 10^7", fontsize=14)
grphik.set_xlabel("Seasons", fontsize=14);
plt.show()

# %% [markdown]
# Вывод: наибольшие цены приходятся на 2 сезон, то есть на весну, скорее всего это связано с тем, что

# %% [markdown]
# ###График 7

# %%
fig, ax = plt.subplots(figsize=(20,20))
box1 = sns.boxplot(data['Area_in_Marla'].loc[data['Area_in_Marla'] < 50], width=0.3)
box1.set_ylabel("Area in Marla", fontsize=20)
plt.show()

# %% [markdown]
# Вывод: Площадь большей части жилья составляет около 178 м^2, что значительно больше площади нормальной квартиры => это земельные участки по типу дач, но малой площади, что свидетельствует о перенаселённости Пакистана

# %% [markdown]
# ### График

# %%
fig, axes = plt.subplots(figsize=(50,50))
#fig.set_facecolor('#87CEFA')
hist1 = sns.countplot(x=data['price']*0.369234, color='#FF6347')
plt.show()

# %% [markdown]
# ##Регрессия

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("levyedgar44/income-and-happiness-correction")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 4.77k/4.77k [00:00<00:00, 5.77MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/levyedgar44/income-and-happiness-correction/versions/1

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/root/.cache/kagglehub/datasets/levyedgar44/income-and-happiness-correction/versions/1/happyscore_income.csv")
data.head(10)
# Out:
#         country  adjusted_satisfaction  avg_satisfaction  std_satisfaction  \
# 0       Armenia                   37.0               4.9              2.42
# 1        Angola                   26.0               4.3              3.19
# 2     Argentina                   60.0               7.1              1.91
# 3       Austria                   59.0               7.2              2.11
# 4     Australia                   65.0               7.6              1.80
# 5    Azerbaijan                   46.0               5.8              2.27
# 6    Bangladesh                   43.0               5.3              2.10
# 7       Belgium                   63.0               7.2              1.72
# 8  Burkina Faso                   37.0               4.4              2.02
# 9      Bulgaria                   34.0               4.6              2.57
#
#    avg_income  median_income  income_inequality  \
# 0    2096.760    1731.506667          31.445556
# ...

# %% [markdown]
# Ну скорее всего GDP - внутренний валовый продукт.
#
# adjusted_satisfaction - какая-то скорректированнная удовлетворённость, т.е. приведённая, наверное, к каким-то одинаковым единицам. Интуитивно кажется, что это в процентах, где 0 - полностью не удовлетворён, а 100 - полностью доволен
#
# avg_satisfaction - какая-то средняя удовлетворённость. Наверное,

# %%
print(data['avg_satisfaction'].max())
print(data['avg_satisfaction'].min())
# Out:
# 8.5
# 2.5

# %%
print(data['adjusted_satisfaction'].max())
print(data['adjusted_satisfaction'].min())
# Out:
# 74.0
# 19.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   country                111 non-null    object
#  1   adjusted_satisfaction  111 non-null    float64
#  2   avg_satisfaction       111 non-null    float64
#  3   std_satisfaction       111 non-null    float64
#  4   avg_income             111 non-null    float64
#  5   median_income          111 non-null    float64
#  6   income_inequality      111 non-null    float64
#  7   region                 111 non-null    object
#  8   happyScore             111 non-null    float64
#  9   GDP                    111 non-null    float64
#  10  country.1              111 non-null    object
# dtypes: float64(8), object(3)
# memory usage: 9.7+ KB

# %%
data.isnull().sum()
# Out:
# country                  0
# adjusted_satisfaction    0
# avg_satisfaction         0
# std_satisfaction         0
# avg_income               0
# median_income            0
# income_inequality        0
# region                   0
# happyScore               0
# GDP                      0
# country.1                0
# dtype: int64

# %%
plt.figure(figsize=(12,10))
corr_matrix = data.corr(numeric_only=True)
sns.heatmap(corr_matrix, xticklabels=data.corr(numeric_only=True).columns, yticklabels=data.corr(numeric_only=True).columns, cmap='Blues', center=0, annot=True)
# color pallete sns
# Decorations
plt.title('Кореллограмма без масштабирования', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# ###Масштабирование

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mmsc = MinMaxScaler()
#X_norm = mmsc.fit_transform(X_train) # type - numpy array
float_cols = data.select_dtypes(include='float64').columns.tolist()
#print(data[float_cols].type())
data_normalized = mmsc.fit_transform(data[float_cols])
data_normalized = pd.DataFrame(data_normalized, columns=float_cols)
#print(data_normalized)
data_normalized.head(10)
# Out:
#    adjusted_satisfaction  avg_satisfaction  std_satisfaction  avg_income  \
# 0               0.327273          0.400000          0.574586    0.059505
# 1               0.127273          0.300000          1.000000    0.034206
# 2               0.745455          0.766667          0.292818    0.254916
# 3               0.727273          0.783333          0.403315    0.737392
# 4               0.836364          0.850000          0.232044    0.755352
# 5               0.490909          0.550000          0.491713    0.109675
# 6               0.436364          0.466667          0.397790    0.027039
# 7               0.800000          0.783333          0.187845    0.648029
# 8               0.327273          0.316667          0.353591    0.011635
# 9               0.272727          0.350000          0.657459    0.186726
#
#    median_income  income_inequality  happyScore       GDP
# 0       0.060300           0.182998    0.318239  0.486184
# ...

# %% [markdown]
# Для масштабирование используем нормализацию, т.к. изначально все данные больше нуля => пусть и остаются больше нуля

# %%
plt.figure(figsize=(12,10))
corr_matrix = data.corr(numeric_only=True)
sns.heatmap(corr_matrix, xticklabels=data.corr(numeric_only=True).columns, yticklabels=data.corr(numeric_only=True).columns, cmap='Blues', center=0, annot=True)
# color pallete sns
# Decorations
plt.title('Кореллограмма с масштабированием', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# ###Разбивка данных и обучение

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
from sklearn.model_selection import train_test_split

# %%
X = data[['avg_satisfaction', 'avg_income', 'GDP']]
Y = data['happyScore']

# 'avg_satisfaction', 'avg_income', 'GDP'

# %% [markdown]
# Наверное, happyScore - целевой параметр.
#
# Из кореллограммы видно, что этот параметр мало зависит от std_satisfaction и income_inequality. Поэтому их брать не будем.
#
# median_income нет смысла брать, т.к. этот параметр однозначно определяется из avg_income.
#
# adjusted_satisfaction также нет смысла брать, т.к. он тоже почти однозначно определяется из avg_satisfaction.
#
# Соответственно берём столбцы, которые взяты в ячейке выше.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3)

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
fig, axes = plt.subplots(2,3,figsize=(10,10))

#hist1 = sns.countplot(ax=axes[0,0], x=data['property_type'], color='#FF6347')

scat1 = sns.scatterplot(ax=axes[0,0], x=X_train['avg_satisfaction'], y=y_train, s = 30)
scat1.set_ylabel("happyScore")
scat1.set_xlabel("avg_satisfaction")
scat1.set_title("Тренировочные данные")

scat2 = sns.scatterplot(ax=axes[0,1], x=X_train['avg_income'], y=y_train, s = 30)
scat2.set_ylabel("happyScore")
scat2.set_xlabel("avg_income")
scat2.set_title("Тренировочные данные")

scat3 = sns.scatterplot(ax=axes[0,2], x=X_train['GDP'], y=y_train, s = 30)
scat3.set_ylabel("happyScore")
scat3.set_xlabel("GDP")
scat3.set_title("Тренировочные данные")

scat4 = sns.scatterplot(ax=axes[1,0], x=X_test['avg_satisfaction'], y=y_test, s = 30)
scat4.set_ylabel("happyScore")
scat4.set_xlabel("avg_satisfaction")
scat4.set_title("Тестовые данные")

scat5 = sns.scatterplot(ax=axes[1,1], x=X_test['avg_income'], y=y_test, s = 30)
scat5.set_ylabel("happyScore")
scat5.set_xlabel("avg_income")
scat5.set_title("Тестовые данные")

scat6 = sns.scatterplot(ax=axes[1,2], x=X_test['GDP'], y=y_test, s = 30)
scat6.set_ylabel("happyScore")
scat6.set_xlabel("GDP")
scat6.set_title("Тестовые данные")

plt.show()

# %%
y_pred = lin_reg.predict(X_test)
#y_pred = pd.Series(y_pred)

print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
print('R2 score:', r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 0.3129888903145968
# Mean Squared Error: 0.17036537496969362
# R2 score: 0.8540197599871053

# %%
w1 = lin_reg.coef_
print(w1)
# Out:
# [ 5.44305974e-01  7.05625762e-05 -1.30384418e-01]

# %% [markdown]
# ###Обучение на нормализованных данных

# %%
X_normalized = data[['avg_satisfaction', 'avg_income', 'GDP']]
Y_normalized = data['happyScore']
X_normalized_train, X_normalized_test, y_normalized_train, y_normalized_test = train_test_split(X_normalized, Y_normalized, test_size=0.3)
lin_reg_normalized = LinearRegression()
lin_reg_normalized.fit(X_normalized_train, y_normalized_train)
# Out:
# LinearRegression()

# %%
y_pred_normalized = lin_reg_normalized.predict(X_normalized_test)
print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
print('R2 score:', r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 0.3186444987984316
# Mean Squared Error: 0.16764437529179674
# R2 score: 0.8553101602444968

# %% [markdown]
# ###Визуализация результата

# %%
fig, axes = plt.subplots(3,figsize=(10,10))


scat4 = sns.scatterplot(ax = axes[0], x=X_test['avg_satisfaction'], y=y_test, s = 30)
scat4.set_ylabel("happyScore")
scat4.set_xlabel("avg_satisfaction")
#scat4.set_title("Тестовые данные с предсказанием")
graphik4 = sns.lineplot(ax=axes[0], x=X_test['avg_satisfaction'], y=y_pred, color='green')

scat5 = sns.scatterplot(ax = axes[1], x=X_test['avg_income'], y=y_test, s = 30)
scat5.set_ylabel("happyScore")
scat5.set_xlabel("avg_income")
#scat5.set_title("Тестовые данные с предсказанием")
graphik5 = sns.lineplot(ax=axes[1], x=X_test['avg_income'], y=y_pred, color='green')

scat6 = sns.scatterplot(ax = axes[2], x=X_test['GDP'], y=y_test, s = 30)
scat6.set_ylabel("happyScore")
scat6.set_xlabel("GDP")
#scat6.set_title("Тестовые данные с предсказанием")
graphik6 = sns.lineplot(ax=axes[2], x=X_test['GDP'], y=y_pred, color='green')

plt.show()

# %%
fig, axes = plt.subplots(3,figsize=(10,10))


scat4 = sns.scatterplot(ax = axes[0], x=X_train['avg_satisfaction'], y=y_train, s = 30)
scat4.set_ylabel("happyScore")
scat4.set_xlabel("avg_satisfaction")
scat4.set_title("Тестовые данные с предсказанием")
graphik4 = sns.lineplot(ax=axes[0], x=X_train['avg_satisfaction'], y=y_pred, color='green')

scat5 = sns.scatterplot(ax = axes[1], x=X_train['avg_income'], y=y_train, s = 30)
scat5.set_ylabel("happyScore")
scat5.set_xlabel("avg_income")
scat5.set_title("Тестовые данные с предсказанием")
graphik5 = sns.lineplot(ax=axes[1], x=X_train['avg_income'], y=y_pred, color='green')

scat6 = sns.scatterplot(ax = axes[2], x=X_train['GDP'], y=y_train, s = 30)
scat6.set_ylabel("happyScore")
scat6.set_xlabel("GDP")
scat6.set_title("Тестовые данные с предсказанием")
graphik6 = sns.lineplot(ax=axes[2], x=X_train['GDP'], y=y_pred, color='green')

plt.show()

# %% [markdown]
# ###Кроссвалидация

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
sklearn.model_selection.cross_val_score(estimator, X, y=None, groups=None, scoring=None, cv=10, n_jobs=None, verbose=0, fit_params=None, pre_dispatch='2*n_jobs', error_score=nan)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-2b150e847b65> in <cell line: 0>()
# ----> 1 sklearn.model_selection.cross_val_score(estimator, X, y=None, groups=None, scoring=None, cv=10, n_jobs=None, verbose=0, fit_params=None, pre_dispatch='2*n_jobs', error_score=nan)
#
# NameError: name 'sklearn' is not defined
